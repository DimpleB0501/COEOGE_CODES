# %%
import rasterio

# Path to your TIFF image
tif_path = "/home/dimple/Desktop/micasense-COEOGEVISIT/imageprocessing/oil_water_cocoformat/train2017/IMG_0025_1_3_Red.tif"  # Change to your file path

with rasterio.open(tif_path) as src:
    print(f"File: {tif_path}")
    print(f"Dimensions: {src.width} × {src.height} pixels")
    print(f"Number of bands: {src.count}")
    print(f"Data type: {src.dtypes[0]}")
    print(f"CRS (coordinate system): {src.crs}")
    print(f"Driver: {src.driver}")
    print(f"Transform: {src.transform}")
    print(f"Bounds: {src.bounds}")
# Out:
# File: /home/dimple/Desktop/micasense-COEOGEVISIT/imageprocessing/oil_water_cocoformat/train2017/IMG_0025_1_3_Red.tif
# Dimensions: 2448 × 2013 pixels
# Number of bands: 1
# Data type: uint16
# CRS (coordinate system): None
# Driver: GTiff
# Transform: | 1.00, 0.00, 0.00|
# | 0.00, 1.00, 0.00|
# | 0.00, 0.00, 1.00|
# Bounds: BoundingBox(left=0.0, bottom=2013.0, right=2448.0, top=0.0)
# /home/dimple/anaconda3/envs/micasense/lib/python3.8/site-packages/rasterio/__init__.py:304: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
